# %%
# import os
# import re
# import json
# from urllib.parse import urlparse, parse_qs
# from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

# # List your YouTube URLs here
# YOUTUBE_URLS = [
#     "https://www.youtube.com/watch?v=HWpW50ByRro&t=29s",
#     "https://www.youtube.com/watch?v=-cOjBanoNP0&t=125s",
#     "https://www.youtube.com/watch?v=3oLz6p5htik",
#     "https://www.youtube.com/watch?v=AZ87z6JVdcQ"
# ]

# OUTPUT_DIR = "transcripts"
# os.makedirs(OUTPUT_DIR, exist_ok=True)

# def extract_video_id(url):
#     """
#     Extract the video ID from a YouTube URL.
#     Handles URLs like:
#     - https://www.youtube.com/watch?v=VIDEO_ID
#     - https://youtu.be/VIDEO_ID
#     """
#     # Parse the URL
#     parsed_url = urlparse(url)

#     if parsed_url.hostname in ["www.youtube.com", "youtube.com"]:
#         query = parse_qs(parsed_url.query)
#         video_id = query.get("v")
#         if video_id:
#             return video_id[0]
#     elif parsed_url.hostname == "youtu.be":
#         return parsed_url.path[1:]
#     return None

# def fetch_and_save_transcript(video_id):
#     try:
#         transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
#         # Combine text parts into one string (with spaces)
#         full_text = " ".join([entry['text'] for entry in transcript_list])

#         # Save plain text transcript
#         txt_path = os.path.join(OUTPUT_DIR, f"{video_id}.txt")
#         with open(txt_path, "w", encoding="utf-8") as f:
#             f.write(full_text)

#         # Save full transcript JSON with timestamps (optional)
#         json_path = os.path.join(OUTPUT_DIR, f"{video_id}_with_timestamps.json")
#         with open(json_path, "w", encoding="utf-8") as f:
#             json.dump(transcript_list, f, indent=2)

#         print(f"✅ Transcript saved for video {video_id}")

#     except TranscriptsDisabled:
#         print(f"❌ Transcripts are disabled for video {video_id}")
#     except NoTranscriptFound:
#         print(f"❌ No transcript found for video {video_id}")
#     except Exception as e:
#         print(f"❌ Error fetching transcript for video {video_id}: {e}")

# def main():
#     for url in YOUTUBE_URLS:
#         video_id = extract_video_id(url)
#         if video_id:
#             print(f"Fetching transcript for video ID: {video_id}")
#             fetch_and_save_transcript(video_id)
#         else:
#             print(f"❌ Could not extract video ID from URL: {url}")

# if __name__ == "__main__":
#     main()
# Out:
# Fetching transcript for video ID: HWpW50ByRro
# ✅ Transcript saved for video HWpW50ByRro
# Fetching transcript for video ID: -cOjBanoNP0
# ✅ Transcript saved for video -cOjBanoNP0
# Fetching transcript for video ID: 3oLz6p5htik
# ✅ Transcript saved for video 3oLz6p5htik
# Fetching transcript for video ID: AZ87z6JVdcQ
# ✅ Transcript saved for video AZ87z6JVdcQ

# %%
# import os
# import re
# import json
# from urllib.parse import urlparse, parse_qs
# from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

# # List your YouTube URLs here
# YOUTUBE_URLS = [
#     "https://www.youtube.com/watch?v=HsMT_XKA4G8",
#     "https://www.youtube.com/watch?v=7ZedbecroYA",
#     "https://www.youtube.com/watch?v=K7HohmszmSA",
   
# ]

# OUTPUT_DIR = "transcripts"
# os.makedirs(OUTPUT_DIR, exist_ok=True)

# def extract_video_id(url):
#     """
#     Extract the video ID from a YouTube URL.
#     Handles URLs like:
#     - https://www.youtube.com/watch?v=VIDEO_ID
#     - https://youtu.be/VIDEO_ID
#     """
#     # Parse the URL
#     parsed_url = urlparse(url)

#     if parsed_url.hostname in ["www.youtube.com", "youtube.com"]:
#         query = parse_qs(parsed_url.query)
#         video_id = query.get("v")
#         if video_id:
#             return video_id[0]
#     elif parsed_url.hostname == "youtu.be":
#         return parsed_url.path[1:]
#     return None

# def fetch_and_save_transcript(video_id):
#     try:
#         transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
#         # Combine text parts into one string (with spaces)
#         full_text = " ".join([entry['text'] for entry in transcript_list])

#         # Save plain text transcript
#         txt_path = os.path.join(OUTPUT_DIR, f"{video_id}.txt")
#         with open(txt_path, "w", encoding="utf-8") as f:
#             f.write(full_text)

#         # Save full transcript JSON with timestamps (optional)
#         json_path = os.path.join(OUTPUT_DIR, f"{video_id}_with_timestamps.json")
#         with open(json_path, "w", encoding="utf-8") as f:
#             json.dump(transcript_list, f, indent=2)

#         print(f"✅ Transcript saved for video {video_id}")

#     except TranscriptsDisabled:
#         print(f"❌ Transcripts are disabled for video {video_id}")
#     except NoTranscriptFound:
#         print(f"❌ No transcript found for video {video_id}")
#     except Exception as e:
#         print(f"❌ Error fetching transcript for video {video_id}: {e}")

# def main():
#     for url in YOUTUBE_URLS:
#         video_id = extract_video_id(url)
#         if video_id:
#             print(f"Fetching transcript for video ID: {video_id}")
#             fetch_and_save_transcript(video_id)
#         else:
#             print(f"❌ Could not extract video ID from URL: {url}")

# if __name__ == "__main__":
#     main()
# Out:
# Fetching transcript for video ID: HsMT_XKA4G8
# ✅ Transcript saved for video HsMT_XKA4G8
# Fetching transcript for video ID: 7ZedbecroYA
# ✅ Transcript saved for video 7ZedbecroYA
# Fetching transcript for video ID: K7HohmszmSA
# ✅ Transcript saved for video K7HohmszmSA

# %%
# import os
# import re
# import json
# from urllib.parse import urlparse, parse_qs
# from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

# # List your YouTube URLs here
# YOUTUBE_URLS = [
#     "https://www.youtube.com/watch?v=TOdnj2p91_c",
#     "https://www.youtube.com/watch?v=T5UHXCrW0gI",
    
   
# ]

# OUTPUT_DIR = "transcripts"
# os.makedirs(OUTPUT_DIR, exist_ok=True)

# def extract_video_id(url):
#     """
#     Extract the video ID from a YouTube URL.
#     Handles URLs like:
#     - https://www.youtube.com/watch?v=VIDEO_ID
#     - https://youtu.be/VIDEO_ID
#     """
#     # Parse the URL
#     parsed_url = urlparse(url)

#     if parsed_url.hostname in ["www.youtube.com", "youtube.com"]:
#         query = parse_qs(parsed_url.query)
#         video_id = query.get("v")
#         if video_id:
#             return video_id[0]
#     elif parsed_url.hostname == "youtu.be":
#         return parsed_url.path[1:]
#     return None

# def fetch_and_save_transcript(video_id):
#     try:
#         transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
#         # Combine text parts into one string (with spaces)
#         full_text = " ".join([entry['text'] for entry in transcript_list])

#         # Save plain text transcript
#         txt_path = os.path.join(OUTPUT_DIR, f"{video_id}.txt")
#         with open(txt_path, "w", encoding="utf-8") as f:
#             f.write(full_text)

#         # Save full transcript JSON with timestamps (optional)
#         json_path = os.path.join(OUTPUT_DIR, f"{video_id}_with_timestamps.json")
#         with open(json_path, "w", encoding="utf-8") as f:
#             json.dump(transcript_list, f, indent=2)

#         print(f"✅ Transcript saved for video {video_id}")

#     except TranscriptsDisabled:
#         print(f"❌ Transcripts are disabled for video {video_id}")
#     except NoTranscriptFound:
#         print(f"❌ No transcript found for video {video_id}")
#     except Exception as e:
#         print(f"❌ Error fetching transcript for video {video_id}: {e}")

# def main():
#     for url in YOUTUBE_URLS:
#         video_id = extract_video_id(url)
#         if video_id:
#             print(f"Fetching transcript for video ID: {video_id}")
#             fetch_and_save_transcript(video_id)
#         else:
#             print(f"❌ Could not extract video ID from URL: {url}")

# if __name__ == "__main__":
#     main()
# Out:
# Fetching transcript for video ID: TOdnj2p91_c
# ✅ Transcript saved for video TOdnj2p91_c
# Fetching transcript for video ID: T5UHXCrW0gI
# ✅ Transcript saved for video T5UHXCrW0gI

# %%
# import os
# import re
# import json
# from urllib.parse import urlparse, parse_qs
# from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

# # List your YouTube URLs here
# YOUTUBE_URLS = [
#     "https://www.youtube.com/watch?v=XlibDPyMnak",
#     "https://www.youtube.com/watch?v=awuTbPVCSH4",
#     "https://www.youtube.com/watch?v=QOukBtky_yg",
#     "https://www.youtube.com/watch?v=BIxv6uFqXEE"
    
   
# ]

# OUTPUT_DIR = "transcripts"
# os.makedirs(OUTPUT_DIR, exist_ok=True)

# def extract_video_id(url):
#     """
#     Extract the video ID from a YouTube URL.
#     Handles URLs like:
#     - https://www.youtube.com/watch?v=VIDEO_ID
#     - https://youtu.be/VIDEO_ID
#     """
#     # Parse the URL
#     parsed_url = urlparse(url)

#     if parsed_url.hostname in ["www.youtube.com", "youtube.com"]:
#         query = parse_qs(parsed_url.query)
#         video_id = query.get("v")
#         if video_id:
#             return video_id[0]
#     elif parsed_url.hostname == "youtu.be":
#         return parsed_url.path[1:]
#     return None

# def fetch_and_save_transcript(video_id):
#     try:
#         transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
#         # Combine text parts into one string (with spaces)
#         full_text = " ".join([entry['text'] for entry in transcript_list])

#         # Save plain text transcript
#         txt_path = os.path.join(OUTPUT_DIR, f"{video_id}.txt")
#         with open(txt_path, "w", encoding="utf-8") as f:
#             f.write(full_text)

#         # Save full transcript JSON with timestamps (optional)
#         json_path = os.path.join(OUTPUT_DIR, f"{video_id}_with_timestamps.json")
#         with open(json_path, "w", encoding="utf-8") as f:
#             json.dump(transcript_list, f, indent=2)

#         print(f"✅ Transcript saved for video {video_id}")

#     except TranscriptsDisabled:
#         print(f"❌ Transcripts are disabled for video {video_id}")
#     except NoTranscriptFound:
#         print(f"❌ No transcript found for video {video_id}")
#     except Exception as e:
#         print(f"❌ Error fetching transcript for video {video_id}: {e}")

# def main():
#     for url in YOUTUBE_URLS:
#         video_id = extract_video_id(url)
#         if video_id:
#             print(f"Fetching transcript for video ID: {video_id}")
#             fetch_and_save_transcript(video_id)
#         else:
#             print(f"❌ Could not extract video ID from URL: {url}")

# if __name__ == "__main__":
#     main()
# Out:
# Fetching transcript for video ID: XlibDPyMnak
# ✅ Transcript saved for video XlibDPyMnak
# Fetching transcript for video ID: awuTbPVCSH4
# ✅ Transcript saved for video awuTbPVCSH4
# Fetching transcript for video ID: QOukBtky_yg
# ✅ Transcript saved for video QOukBtky_yg
# Fetching transcript for video ID: BIxv6uFqXEE
# ✅ Transcript saved for video BIxv6uFqXEE

# %%
import os
import re
import json
from urllib.parse import urlparse, parse_qs
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, NoTranscriptFound

# List your YouTube URLs here
YOUTUBE_URLS = [
    "https://www.youtube.com/watch?v=sRjkmxFvlZQ&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=1",
    "https://www.youtube.com/watch?v=9NGajZhp-C0&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=2",
    "https://www.youtube.com/watch?v=AJuIjabQPdE&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=3",
    "https://www.youtube.com/watch?v=LCYINIELH2w&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=4",
    "https://www.youtube.com/watch?v=yXl-zVTZxr8&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=5",
    "https://www.youtube.com/watch?v=KUg_u99k8ww&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=6",
    "https://www.youtube.com/watch?v=ANjA7TEfezE&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=7",
    "https://www.youtube.com/watch?v=60qB-CFiE_w&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=8",
    "https://www.youtube.com/watch?v=oyzR7tMmj9o&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=9",
    "https://www.youtube.com/watch?v=Eac2jZcelQw&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=10",
    "https://www.youtube.com/watch?v=h7WIV4WspL0&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=11",
    "https://www.youtube.com/watch?v=ddBRWQ907Uo&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=12",
    "https://www.youtube.com/watch?v=P9y63shSPfY&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=13",
    "https://www.youtube.com/watch?v=M-03sb8DvFo&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=14",
    "https://www.youtube.com/watch?v=OuDCDp9Z9Y4&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=15",
    "https://www.youtube.com/watch?v=Ssi1U6aMCdU&list=PLGBVJB1zelfHU6nPKTTNcJh2FXyXsYHij&index=16"
    
   
]

OUTPUT_DIR = "transcripts"
os.makedirs(OUTPUT_DIR, exist_ok=True)

def extract_video_id(url):
    """
    Extract the video ID from a YouTube URL.
    Handles URLs like:
    - https://www.youtube.com/watch?v=VIDEO_ID
    - https://youtu.be/VIDEO_ID
    """
    # Parse the URL
    parsed_url = urlparse(url)

    if parsed_url.hostname in ["www.youtube.com", "youtube.com"]:
        query = parse_qs(parsed_url.query)
        video_id = query.get("v")
        if video_id:
            return video_id[0]
    elif parsed_url.hostname == "youtu.be":
        return parsed_url.path[1:]
    return None

def fetch_and_save_transcript(video_id):
    try:
        transcript_list = YouTubeTranscriptApi.get_transcript(video_id)
        # Combine text parts into one string (with spaces)
        full_text = " ".join([entry['text'] for entry in transcript_list])

        # Save plain text transcript
        txt_path = os.path.join(OUTPUT_DIR, f"{video_id}.txt")
        with open(txt_path, "w", encoding="utf-8") as f:
            f.write(full_text)

        # Save full transcript JSON with timestamps (optional)
        json_path = os.path.join(OUTPUT_DIR, f"{video_id}_with_timestamps.json")
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(transcript_list, f, indent=2)

        print(f"✅ Transcript saved for video {video_id}")

    except TranscriptsDisabled:
        print(f"❌ Transcripts are disabled for video {video_id}")
    except NoTranscriptFound:
        print(f"❌ No transcript found for video {video_id}")
    except Exception as e:
        print(f"❌ Error fetching transcript for video {video_id}: {e}")

def main():
    for url in YOUTUBE_URLS:
        video_id = extract_video_id(url)
        if video_id:
            print(f"Fetching transcript for video ID: {video_id}")
            fetch_and_save_transcript(video_id)
        else:
            print(f"❌ Could not extract video ID from URL: {url}")

if __name__ == "__main__":
    main()
# Out:
# Fetching transcript for video ID: sRjkmxFvlZQ
# ✅ Transcript saved for video sRjkmxFvlZQ
# Fetching transcript for video ID: 9NGajZhp-C0
# ✅ Transcript saved for video 9NGajZhp-C0
# Fetching transcript for video ID: AJuIjabQPdE
# ✅ Transcript saved for video AJuIjabQPdE
# Fetching transcript for video ID: LCYINIELH2w
# ✅ Transcript saved for video LCYINIELH2w
# Fetching transcript for video ID: yXl-zVTZxr8
# ✅ Transcript saved for video yXl-zVTZxr8
# Fetching transcript for video ID: KUg_u99k8ww
# ✅ Transcript saved for video KUg_u99k8ww
# Fetching transcript for video ID: ANjA7TEfezE
# ✅ Transcript saved for video ANjA7TEfezE
# Fetching transcript for video ID: 60qB-CFiE_w
# ✅ Transcript saved for video 60qB-CFiE_w
# Fetching transcript for video ID: oyzR7tMmj9o
# ✅ Transcript saved for video oyzR7tMmj9o
# Fetching transcript for video ID: Eac2jZcelQw
# ✅ Transcript saved for video Eac2jZcelQw
# Fetching transcript for video ID: h7WIV4WspL0
# ...
